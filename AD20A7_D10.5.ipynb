# %% [markdown]
# # Update the name and the excel area

# %%
NAME = 'AD20A7_D10.5'
EXCEL_AREA = 'A1:M1000'

# %%
from helpers import *
import pickle
import os.path
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
data_name = NAME + '.pickle'
if os.path.exists(data_name):
    with open(data_name, mode='rb') as f:
        data = pickle.load(f)
else:
    app = get_app()
    analysisbook = get_analysisbook(app)
    data = analysisbook.sheets['GraphOrdering'].range(EXCEL_AREA).value
    data = pandas.DataFrame(data[1:], columns=data[0])
    data['Sample'] = np.array([str(x) for x in data['Sample']])
    data['Sample_show'] = np.array([map_show(x) for x in data['Sample']])
    with open(data_name, mode='wb') as f:
        pickle.dump(data, f)

# %%
data_name
# Out:
# 'AD20A7_D10.5.pickle'

# %%
#rm 'AD20A7_D10.5.pickle'

# %%
genes = [x for x in data["Gene"].unique() if x is not None]#takes each unique gene and put in a list
samples = [str(x) for x in data['Sample'].unique() if x is not None and x is not 'None']#take each unique sample sample #
conditions = data['Sample'].unique()#this is calling the codndions for the y axis on the legend plot
conditions = list(data.columns)#make the list the right way
conditions.remove('Sample')
conditions.remove('R1')
conditions.remove('R2')
conditions.remove('R3')
conditions.remove('Gene')
conditions.remove('Sample_show')
samples.remove('None')

# %% [markdown]
# # Check if all conditions have a color

# %%
colors = {'Cell Line':'Black',
          'SHF':'#124be6',
          'FHF':'#e69c12',
          'CHSBRA':'#800000',
          'XAVSBRA':'#48a10d',
          'CH4':'#1a83b8',
         'CH6':'#BCC2C2',
         'CH8':'#757575',
         'Density':'Black',
         'Collection':'Black',
         'D1.5-D3.5':'Black',
         'A50':'#beaec2',
         'FGF':'#ff7700',
         'Insulin':'#00f587',
         'CH1.5 D5':'#1a83b8'}

# %%
text_conditions = [
    "Cell Line",
    'Density',
    'Collection',
    'D1.5-D3.5']

# %%
for condition in conditions:
    if condition not in colors:
        print(f'Condition {condition} doesnt have a color, insert it and run again!')

# %%
#makes a plot for each gene
for gene in genes:
    plots = plot_data(data.loc[data["Gene"] == gene], conditions, title=gene, xaxis=samples, colors=colors, text_conditions=text_conditions)
    show(plots)
# Out:
# /Users/alison.deyett/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/alison.deyett/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#   <div class="bk-root" id="0b436a43-be12-4993-9cf6-5e8b8db2bffe" data-root-id="1138"></div>
#   <div class="bk-root" id="5a1eb273-0d07-4811-982a-c0572f1d2a2f" data-root-id="1504"></div>
#   <div class="bk-root" id="c8683156-fded-411b-8683-b4b4fb301121" data-root-id="1903"></div>
#   <div class="bk-root" id="fd0ecbeb-27d4-4e2c-8b7a-51d411a5481c" data-root-id="2335"></div>
#   <div class="bk-root" id="a98a7c22-f4a0-4f1b-9413-015cbd6b9d97" data-root-id="2800"></div>
#   <div class="bk-root" id="9b10cb4e-405c-4fcd-b54d-24c53778c83e" data-root-id="3298"></div>
#   <div class="bk-root" id="f29fbe88-af60-463d-b33a-3574c24859ad" data-root-id="3829"></div>
#   <div class="bk-root" id="dc15c380-c0c1-40b3-aa2a-9924c681f395" data-root-id="4393"></div>

# %%
#makes a plot for each gene
for gene in genes:
    plots = plot_data(data.loc[data["Gene"] == gene], conditions, title=gene, xaxis=samples, colors=colors)
    export_as_svg(plots, NAME+gene)
# Out:
# /Users/alison.deyett/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/alison.deyett/Library/Python/3.7/lib/python/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
